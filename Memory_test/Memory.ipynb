# %%
import requests
from bs4 import BeautifulSoup
import json

def send_to_google_form(data_dict, form_url):
    ''' Helper function to upload information to a corresponding google form 
        You are not expected to follow the code within this function!
    '''
    form_id = form_url[34:90]
    view_form_url = f'https://docs.google.com/forms/d/e/{form_id}/viewform'
    post_form_url = f'https://docs.google.com/forms/d/e/{form_id}/formResponse'

    page = requests.get(view_form_url)
    content = BeautifulSoup(page.content, "html.parser").find('script', type='text/javascript')
    content = content.text[27:-1]
    result = json.loads(content)[1][1]
    form_dict = {}
    
    loaded_all = True
    for item in result:
        if item[1] not in data_dict:
            print(f"Form item {item[1]} not found. Data not uploaded.")
            loaded_all = False
            return False
        form_dict[f'entry.{item[4][0][0]}'] = data_dict[item[1]]
    
    post_result = requests.post(post_form_url, data=form_dict)
    return post_result.ok

# %%
from IPython.display import display, Image, clear_output
import time
import random

print("Welcome to the Memory Test!") # start test
time.sleep(2)
clear_output(wait=False)

print("Please read:")

print("")

print("we wish to record your response data")

print("to an anonymised public data repository. ")

print("Your data will be used for educational teaching purposes")

print("practising data analysis and visualisation.")

print("")

print("Please type yes in the box below if you consent to the upload.")

result = input("> ")

if result == "yes":

print("Thanks - your data will be uploaded.")

#send_to_google_form(data_dict, form_url)

else:

print("No problem we hope you enjoyed the test.")

def display_level_and_image(level, image_path, time_to_memorize):
    print(f"Level {level}")
    time.sleep(2)
    clear_output(wait=False)
    
    print(f"You have {time_to_memorize} seconds to memorize this image.")
    time.sleep(2)
    
    display(Image(image_path, width=300))
    time.sleep(time_to_memorize)
    clear_output(wait=False)

def ask_questions(questions_and_answers, num_questions):
    correct_answers = 0
    
    for question, choices, correct_choice in random.sample(questions_and_answers, num_questions):
        print(question)
        for choice in choices:
            print(choice)
    
        user_answer = input("Your answer (enter the letter corresponding to your choice): ").lower()
        
        if user_answer == correct_choice:
            print("Correct! Well done!")
            correct_answers += 1
        else:
            print(f"Wrong! The correct answer is: {correct_choice}")
            
        time.sleep(2)
        clear_output(wait=False)
    
    return correct_answers


# Initialize correct_answers variable
correct_answers = 0

# Level 1
display_level_and_image(1, "Lv.1.jpg", 5)
questions_and_answers_level1 = [
    ("What is the shape below the circle?", ["a) square", "b) triangle", "c) circle"], "a")
]
correct_answers += ask_questions(questions_and_answers_level1, 1)
ans1 = questions_and_answers_level1

# Level 2
display_level_and_image(2, "Lv.2.jpg", 5)
questions_and_answers_level2 = [
    ("What is the shape above the triangle?", ["a) square", "b) cross", "c) triangle"], "b"),
    ("What is the color of the circle?", ["a) red", "b) blue", "c) green"], "a"),
]
correct_answers += ask_questions(questions_and_answers_level2, 2)
ans2 = questions_and_answers_level2

# Level 3
display_level_and_image(3, "Lv.3.jpg", 7)
questions_and_answers_level3 = [
    ("What is the shape in the middle column?", ["a) star", "b) circle", "c) square"], "a"),
    ("What is the shape below the star?", ["a) circle", "b) exclamation mark", "c) question mark"], "c"),
]
correct_answers += ask_questions(questions_and_answers_level3, 2)
ans3 = questions_and_answers_level3

# Level 4
display_level_and_image(4, "Lv.3.1.jpg", 7)
questions_and_answers_level4 = [
    ("What is the shape in the middle column?", ["a) star", "b) triangle", "c) square"], "b"),
    ("What is the shape above the star?", ["a) question mark", "b) exclamation mark", "c) star"], "b"),
    ("What is the color of the moon?", ["a) green", "b) blue", "c) red"], "a"),
]
correct_answers += ask_questions(questions_and_answers_level4, 3)
ans4 = questions_and_answers_level4

# Level 5
display_level_and_image(5, "Lv.4.jpg", 10)
questions_and_answers_level5 = [
    ("What is the shape in the middle column?", ["a) star", "b) equal sign", "c) division sign"], "c"),
    ("What is the shape above the star?", ["a) question mark", "b) exclamation mark", "c) star"], "b"),
    ("What is the color of the percentage sign?", ["a) green", "b) blue", "c) red"], "c"),
]
correct_answers += ask_questions(questions_and_answers_level5, 3)
ans5 = questions_and_answers_level5

# Level 6
display_level_and_image(6, "Lv.4.1.jpg", 10)
questions_and_answers_level6 = [
    ("What is the shape in the upper left column?", ["a) star", "b) exclamation mark", "c) division sign"], "b"),
    ("What is the shape above the star?", ["a) question mark", "b) exclamation mark", "c) cross"], "c"),
    ("What is the color of the AT sign (@)?", ["a) green", "b) blue", "c) red"], "a"),
    ("What is the color of the equal sign?", ["a) green", "b) blue", "c) red"], "c"),
]
correct_answers += ask_questions(questions_and_answers_level6, 4)
ans6 = questions_and_answers_level6

# Level 7
display_level_and_image(7, "Lv.5.1.jpg", 15)
questions_and_answers_level7 = [
    ("What is the shape in the upper right column?", ["a) star", "b) exclamation mark", "c) division sign"], "b"),
    ("What is the shape below the plus sign?", ["a) question mark", "b) exclamation mark", "c) cross"], "a"),
    ("What is the color of the AT sign (@)?", ["a) green", "b) blue", "c) red"], "c"),
    ("What is the color of the equal sign?", ["a) green", "b) blue", "c) red"], "a"),
]
correct_answers += ask_questions(questions_and_answers_level7, 4)
ans7 = questions_and_answers_level7

# Level 8
display_level_and_image(8, "Lv.5.jpg", 17)
questions_and_answers_level8 = [
    ("What is the color of the wifi sign?", ["a) green", "b) blue", "c) red"], "a"),
    ("What is the color of the moon sign?", ["a) green", "b) blue", "c) red"], "b"),
    ("What is the color of the plus sign?", ["a) green", "b) blue", "c) red"], "b"),
    ("What is the color of the star?", ["a) green", "b) blue", "c) red"], "c"),
]
correct_answers += ask_questions(questions_and_answers_level8, 4)
ans8 = questions_and_answers_level8

print(f"You've got {correct_answers}/23 answers correct!")

total_questions = 23
accuracy = (correct_answers / total_questions) * 100
print(f"Your accuracy is: {accuracy:.2f}%")



#send_to_google_form(data_dict, form_url)

else:

print("No problem we hope you enjoyed the test.")

data_dict = {

    'Answer 1': ans1,

    'Answer 2': ans2,

    'Answer 3': ans3,

    'Answer 4': ans4,

    'Answer 5': ans5,

    'Answer 6': ans6,

    'Answer 7': ans7,

    'Answer 8': ans8

}

form_url = 'https://docs.google.com/forms/d/1sSUVz4guC5gxoNt8n3lO533iOgKhHMeDoslFxZ4RaUQ/edit?pli=1'

send_to_google_form(data_dict, form_url)
# Out:
# You've got 8/23 answers correct!
# Your accuracy is: 34.78%
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 153
#     131 data_dict = {
#     132
#     133     'Answer 1': ans1,
#    (...)
#     148
#     149 }
#     151 form_url = 'https://docs.google.com/forms/d/1sSUVz4guC5gxoNt8n3lO533iOgKhHMeDoslFxZ4RaUQ/edit?pli=1'
# --> 153 send_to_google_form(data_dict, form_url)
#
# Cell In[1], line 15, in send_to_google_form(data_dict, form_url)
#      13 page = requests.get(view_form_url)
#      14 content = BeautifulSoup(page.content, "html.parser").find('script', type='text/javascript')
# ---> 15 content = content.text[27:-1]
#      16 result = json.loads(content)[1][1]
#      17 form_dict = {}
#
# AttributeError: 'NoneType' object has no attribute 'text'
