# %%
data_consent_info = """DATA CONSENT INFORMATION:

Please read:

we wish to record your response data

to an anonymised public data repository.

Your data will be used for educational teaching purposes

practising data analysis and visualisation.

Please type yes in the box below if you consent to the upload."""

print(data_consent_info)

result = input("> ")

if result == "yes":

    print("Thanks for your participation.")
    
    print("Please contact philip.lewis@ucl.ac.uk")
    
    print("If you have any questions or concerns")
    
    print("regarding the stored results.")

else:

    # end code execution by raising an exception
    
    raise(Exception("User did not consent to continue test."))
# Out:
# DATA CONSENT INFORMATION:
#
# Please read:
#
# we wish to record your response data
#
# to an anonymised public data repository.
#
# Your data will be used for educational teaching purposes
#
# practising data analysis and visualisation.
#
# Please type yes in the box below if you consent to the upload.
# >  yes
# Thanks for your participation.
# Please contact philip.lewis@ucl.ac.uk
# If you have any questions or concerns
# regarding the stored results.

# %%
import random as rnd
import random
import time
from IPython.display import display, clear_output
import requests
from bs4 import BeautifulSoup
import json
import time

response_time1=[]
results = []                                        
score=0


id_instructions = """

Enter your anonymised ID

To generate an anonymous 4-letter unique user identifier please enter:

- two letters based on the initials (first and last name) of a childhood friend

- two letters based on the initials (first and last name) of a favourite actor / actress
"""
print(id_instructions)
user_id = input("> ")
print("User entered id:", user_id)




print("Welcome to the math test")
time.sleep(3)
clear_output(wait=False)
print("You need to answer the follow questions one by one, and each part of questions will be shown for 3 seconds")
time.sleep(4)
clear_output(wait=False)
print("There are 19 questions totally")
time.sleep(3)


random.seed(5)

for x in range(2):
    start_time = time.time()
    num1=random.randint(0,10)
    num2=random.randint(0,10)
    print("what is", num1, "+",num2)
    time.sleep(3)
    clear_output(wait=False)
    user_answer=int(input(" "))
    answer=num1+num2
    end_time = time.time()
    response_time =  end_time - start_time
    response_time1.append(float(response_time))
    if (user_answer==answer):
        print("correct, score +1")
        time.sleep(2)
        score +=1
    else:
        print("wrong")
        time.sleep(2)
    clear_output(wait=False)

for x in range(2):
    num1=random.randint(10,50)
    num2=random.randint(10,30)
    print("what is", num1, "+",num2)
    time.sleep(3)
    clear_output(wait=False)
    user_answer=int(input(" "))
    answer=num1+num2
    end_time = time.time()
    response_time =  end_time - start_time
    response_time1.append(float(response_time))
    if (user_answer==answer):
        print("correct, score +1")
        time.sleep(2)
        score +=1
    else:
        print("wrong")
        time.sleep(2)
    clear_output(wait=False)
    
for x in range(3):
    num1=random.randint(1,20)
    num2=random.randint(1,10)
    num3=random.randint(1,10)
    print("what is", num1, "+",num2, "*",num3)
    time.sleep(3)
    clear_output(wait=False)
    user_answer=int(input(" "))
    answer=num1+num2*num3
    end_time = time.time()
    response_time =  end_time - start_time
    response_time1.append(float(response_time))
    if (user_answer==answer):
        print("correct, score +1")
        time.sleep(2)
        score +=1
    else:
        print("wrong")
        time.sleep(2)
    clear_output(wait=False)

for x in range(3):
    num1=random.randint(1,10)
    num2=random.randint(1,10)
    num3=random.randint(1,10)
    num4=random.randint(1,10)
    print("what is", num1, "*",num2, "+",num3, "*", num4)
    time.sleep(3)
    clear_output(wait=False)
    user_answer=int(input(" "))
    answer=num1*num2+num3*num4
    end_time = time.time()
    response_time =  end_time - start_time
    response_time1.append(float(response_time))
    if (user_answer==answer):
        print("correct, score +1")
        time.sleep(2)
        score +=1
    else:
        print("wrong")
        time.sleep(2)
    clear_output(wait=False)

for x in range(2):
    num1=random.randint(1,10)
    num2=random.randint(1,10)
    num3=random.randint(1,10)
    num4=random.randint(1,10)
    print("what is", num1)
    time.sleep(3)
    clear_output(wait=False)
    print("+",num2)
    time.sleep(3)
    clear_output(wait=False)
    print("-",num3)
    time.sleep(3)
    clear_output(wait=False)
    print("*", num4)
    time.sleep(3)
    clear_output(wait=False)
    user_answer=int(input(" "))
    answer=num1+num2-num3*num4
    end_time = time.time()
    response_time =  end_time - start_time
    response_time1.append(float(response_time))
    if (user_answer==answer):
        print("correct, score +1")
        time.sleep(2)
        score +=1
    else:
        print("wrong")
        time.sleep(2)
    clear_output(wait=False)

for x in range(2):
    num1=random.randint(1,10)
    num2=random.randint(1,10)
    num3=random.randint(1,10)
    num4=random.randint(1,10)
    print("what is","(", num1, "+",num2,")")
    time.sleep(3)
    clear_output(wait=False)
    print("*",num3)
    time.sleep(3)
    clear_output(wait=False)
    print("-", num4)
    time.sleep(3)
    clear_output(wait=False)
    user_answer=int(input(" "))
    answer=(num1+num2)*num3-num4
    end_time = time.time()
    response_time =  end_time - start_time
    response_time1.append(float(response_time))
    if (user_answer==answer):
        print("correct, score +1")
        time.sleep(2)
        score +=1
    else:
        print("wrong")
        time.sleep(2)
    clear_output(wait=False)

for x in range(2):
    num1=random.randint(1,10)
    num2=random.randint(1,10)
    num3=random.randint(1,10)
    num4=random.randint(1,10)
    print("what is", num1)
    time.sleep(3)
    clear_output(wait=False)
    print("+","(",num2, "*",num3,")")
    time.sleep(3)
    clear_output(wait=False)
    print("-", num4)
    time.sleep(3)
    clear_output(wait=False)
    user_answer=int(input(" "))
    answer=num1+(num2*num3)-num4
    end_time = time.time()
    response_time =  end_time - start_time
    response_time1.append(float(response_time))
    if (user_answer==answer):
        print("correct, score +1")
        time.sleep(2)
        score +=1
    else:
        print("wrong")
        time.sleep(2)
    clear_output(wait=False)

for x in range(1):
    num5=11
    print("what is", num5)
    time.sleep(3)
    clear_output(wait=False)
    print("*",num5,)
    time.sleep(3)
    clear_output(wait=False)
    user_answer=int(input(" "))
    answer=num5*num5
    end_time = time.time()
    response_time =  end_time - start_time
    response_time1.append(float(response_time))
    if (user_answer==answer):
        print("correct, score +1")
        time.sleep(2)
        score +=1
    else:
        print("wrong")
        time.sleep(2)
    clear_output(wait=False)
    
for x in range(2):
    num1=random.randint(100,110)
    num2=random.randint(10,11)
    num4=random.randint(1,10)
    num5=random.randint(11,18)
    print("what is", num1)
    time.sleep(3)
    clear_output(wait=False)
    print("-")
    print("(",num2, "*",num5,")")
    time.sleep(3)
    clear_output(wait=False)
    print("+", num4)
    time.sleep(3)
    clear_output(wait=False)
    user_answer=int(input(" "))
    answer=num1-(num2*num5)+num4
    end_time = time.time()
    response_time =  end_time - start_time
    response_time1.append(float(response_time))
    if (user_answer==answer):
        print("correct, score +1")
        time.sleep(2)
        score +=1
    else:
        print("wrong")
        time.sleep(2)
    clear_output(wait=False)

sum1=sum(response_time1)
response_time1[-1]
print("your final score is", score)
print(f"Well done! your time was {response_time:.3f}")
print(f"The average time for each response was {response_time1[-1]/19}")


    
results_dict = {

'participant id':user_id,

'final score':score,

'average time':response_time1[-1]/19,

}

def send_to_google_form(data_dict, form_url):
    ''' Helper function to upload information to a corresponding google form 
        You are not expected to follow the code within this function!
    '''
    form_id = form_url[34:90]
    view_form_url = f'https://docs.google.com/forms/d/e/{form_id}/viewform'
    post_form_url = f'https://docs.google.com/forms/d/e/{form_id}/formResponse'

    page = requests.get(view_form_url)
    content = BeautifulSoup(page.content, "html.parser").find('script', type='text/javascript')
    content = content.text[27:-1]
    result = json.loads(content)[1][1]
    form_dict = {}
    
    loaded_all = True
    for item in result:
        if item[1] not in data_dict:
            print(f"Form item {item[1]} not found. Data not uploaded.")
            loaded_all = False
            return False
        form_dict[f'entry.{item[4][0][0]}'] = data_dict[item[1]]
    
    post_result = requests.post(post_form_url, data=form_dict)
    return post_result.ok

#sends to form
form_url = 'https://docs.google.com/forms/d/1aWFBePAVW0sTApncDqDQ9J78k2fmpzrQ7SzYTVd4dIo/edit'
send_to_google_form(results_dict, form_url)
# Out:
# your final score is 19
# Well done! your time was 184.811
# The average time for each response was 9.726890739641691
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 311
#     309 #sends to form
#     310 form_url = 'https://docs.google.com/forms/d/1aWFBePAVW0sTApncDqDQ9J78k2fmpzrQ7SzYTVd4dIo/edit'
# --> 311 send_to_google_form(results_dict, form_url)
#
# Cell In[15], line 294, in send_to_google_form(data_dict, form_url)
#     292 page = requests.get(view_form_url)
#     293 content = BeautifulSoup(page.content, "html.parser").find('script', type='text/javascript')
# --> 294 content = content.text[27:-1]
#     295 result = json.loads(content)[1][1]
#     296 form_dict = {}
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# ######
